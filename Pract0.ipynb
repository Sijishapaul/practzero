# %% [markdown]
# #Exp0:Introduction to python

# %%
# sijisha paul- 25070123138
print("chotu paul")
# Out:
# chotu paul

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %% [markdown]
# # exploratory data analysis
# ## basics of python
# ### python

# %%
x=2
y=[1,2,5]
z="sijisha paul"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# sijisha paul
